# %%
# run vw script
# !sh oaa.sh
# !sh ect.sh
# Out:
#
# -------------------oaa train------------------------
# -------------------round: 1--------------------
# -------------------step: .06--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.06
# initial_t = 1
# power_t = 0.5
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0       22        8      618
# 0.875000 0.812500           32           32.0        5        5      616
# 0.859375 0.843750           64           64.0       20       26      616
# 0.859375 0.859375          128          128.0       14       14      618
# 0.687500 0.515625          256          256.0        4        1      616
# 0.572266 0.457031          512          512.0        4        1      616
# 0.435547 0.298828         1024         1024.0        3        3      616
# 0.314453 0.193359         2048         2048.0       11       16      617
# 0.221436 0.128418         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.171873
# total feature number = 4317437
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 1--------------------
# --------------------step: .06---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.093750 0.125000           32           32.0        5        5      616
# 0.046875 0.000000           64           64.0       20       20      616
# 0.054688 0.062500          128          128.0       14       14      618
# 0.042969 0.031250          256          256.0        4        4      616
# 0.044922 0.046875          512          512.0        4        4      616
# 0.054688 0.064453         1024         1024.0        3        3      616
# 0.053711 0.052734         2048         2048.0       11       11      617
# 0.056396 0.059082         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.060334
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 1--------------------
# -------------------step: .12--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.12
# initial_t = 1
# power_t = 0.5
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0       22        8      618
# 0.937500 0.937500           32           32.0        5        4      616
# 0.890625 0.843750           64           64.0       20       23      616
# 0.882812 0.875000          128          128.0       14       14      618
# 0.734375 0.585938          256          256.0        4        1      616
# 0.632812 0.531250          512          512.0        4        1      616
# 0.497070 0.361328         1024         1024.0        3        3      616
# 0.371094 0.245117         2048         2048.0       11       10      617
# 0.271240 0.171387         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.213236
# total feature number = 4317437
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 1--------------------
# --------------------step: .12---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.062500 0.062500           32           32.0        5        5      616
# 0.046875 0.031250           64           64.0       20       20      616
# 0.062500 0.078125          128          128.0       14       14      618
# 0.058594 0.054688          256          256.0        4        4      616
# 0.054688 0.050781          512          512.0        4        4      616
# 0.071289 0.087891         1024         1024.0        3        3      616
# 0.071289 0.071289         2048         2048.0       11       11      617
# 0.075439 0.079590         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.078306
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 1--------------------
# -------------------step: .25--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.25
# initial_t = 1
# power_t = 0.5
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0       22        8      618
# 0.937500 0.937500           32           32.0        5        4      616
# 0.890625 0.843750           64           64.0       20       26      616
# 0.898438 0.906250          128          128.0       14       14      618
# 0.761719 0.625000          256          256.0        4        1      616
# 0.648438 0.535156          512          512.0        4        1      616
# 0.526367 0.404297         1024         1024.0        3        3      616
# 0.406738 0.287109         2048         2048.0       11       10      617
# 0.310791 0.214844         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.253744
# total feature number = 4317437
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 1--------------------
# --------------------step: .25---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.062500 0.062500           32           32.0        5        5      616
# 0.062500 0.062500           64           64.0       20       20      616
# 0.078125 0.093750          128          128.0       14       14      618
# 0.082031 0.085938          256          256.0        4        4      616
# 0.091797 0.101562          512          512.0        4        4      616
# 0.094727 0.097656         1024         1024.0        3        3      616
# 0.098633 0.102539         2048         2048.0       11       11      617
# 0.105957 0.113281         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.109827
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 1--------------------
# -------------------step: .50--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 1
# power_t = 0.5
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0       22        8      618
# 0.937500 0.937500           32           32.0        5        4      616
# 0.875000 0.812500           64           64.0       20       26      616
# 0.875000 0.875000          128          128.0       14       14      618
# 0.742188 0.609375          256          256.0        4        1      616
# 0.652344 0.562500          512          512.0        4        5      616
# 0.550781 0.449219         1024         1024.0        3        3      616
# 0.439453 0.328125         2048         2048.0       11       10      617
# 0.347168 0.254883         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.282984
# total feature number = 4317437
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 1--------------------
# --------------------step: .50---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.250000 0.500000            8            8.0       14       13      613
# 0.125000 0.000000           16           16.0       22       22      618
# 0.093750 0.062500           32           32.0        5        5      616
# 0.078125 0.062500           64           64.0       20       20      616
# 0.109375 0.140625          128          128.0       14       14      618
# 0.097656 0.085938          256          256.0        4        4      616
# 0.117188 0.136719          512          512.0        4        4      616
# 0.125977 0.134766         1024         1024.0        3        3      616
# 0.124512 0.123047         2048         2048.0       11       11      617
# 0.134277 0.144043         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.139638
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 1--------------------
# -------------------step: 1--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 1
# initial_t = 1
# power_t = 0.5
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0       22        8      618
# 0.937500 0.937500           32           32.0        5        4      616
# 0.875000 0.812500           64           64.0       20       26      616
# 0.867188 0.859375          128          128.0       14       14      618
# 0.750000 0.632812          256          256.0        4        1      616
# 0.667969 0.585938          512          512.0        4        4      616
# 0.570312 0.472656         1024         1024.0        3        3      616
# 0.464844 0.359375         2048         2048.0       11       16      617
# 0.368652 0.272461         4096         4096.0       16        1      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.306518
# total feature number = 4317437
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 1--------------------
# --------------------step: 1---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.250000 0.500000            8            8.0       14       13      613
# 0.187500 0.125000           16           16.0       22        4      618
# 0.156250 0.125000           32           32.0        5        5      616
# 0.109375 0.062500           64           64.0       20       20      616
# 0.101562 0.093750          128          128.0       14       14      618
# 0.097656 0.093750          256          256.0        4        4      616
# 0.125000 0.152344          512          512.0        4        4      616
# 0.135742 0.146484         1024         1024.0        3        3      616
# 0.135742 0.135742         2048         2048.0       11       11      617
# 0.146240 0.156738         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.149194
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 1--------------------
# -------------------step: 2--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 2
# initial_t = 1
# power_t = 0.5
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0       22        8      618
# 0.937500 0.937500           32           32.0        5        4      616
# 0.890625 0.843750           64           64.0       20       26      616
# 0.882812 0.875000          128          128.0       14       14      618
# 0.781250 0.679688          256          256.0        4        1      616
# 0.687500 0.593750          512          512.0        4        5      616
# 0.584961 0.482422         1024         1024.0        3        3      616
# 0.462891 0.340820         2048         2048.0       11        1      617
# 0.374023 0.285156         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.310084
# total feature number = 4317437
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 1--------------------
# --------------------step: 2---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.250000 0.500000            8            8.0       14       13      613
# 0.187500 0.125000           16           16.0       22        4      618
# 0.187500 0.187500           32           32.0        5        5      616
# 0.125000 0.062500           64           64.0       20       20      616
# 0.125000 0.125000          128          128.0       14       14      618
# 0.128906 0.132812          256          256.0        4        4      616
# 0.156250 0.183594          512          512.0        4        4      616
# 0.161133 0.166016         1024         1024.0        3        3      616
# 0.159668 0.158203         2048         2048.0       11        1      617
# 0.166504 0.173340         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.169305
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 1--------------------
# -------------------step: 4--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 4
# initial_t = 1
# power_t = 0.5
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0       22        8      618
# 0.937500 0.937500           32           32.0        5        4      616
# 0.890625 0.843750           64           64.0       20       26      616
# 0.882812 0.875000          128          128.0       14       14      618
# 0.785156 0.687500          256          256.0        4        1      616
# 0.683594 0.582031          512          512.0        4        5      616
# 0.585938 0.488281         1024         1024.0        3        3      616
# 0.473633 0.361328         2048         2048.0       11       16      617
# 0.379639 0.285645         4096         4096.0       16        1      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.315504
# total feature number = 4317437
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 1--------------------
# --------------------step: 4---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.250000 0.500000            8            8.0       14       13      613
# 0.187500 0.125000           16           16.0       22        4      618
# 0.187500 0.187500           32           32.0        5        5      616
# 0.125000 0.062500           64           64.0       20       20      616
# 0.101562 0.078125          128          128.0       14       14      618
# 0.097656 0.093750          256          256.0        4        4      616
# 0.130859 0.164062          512          512.0        4        4      616
# 0.158203 0.185547         1024         1024.0        3        3      616
# 0.165039 0.171875         2048         2048.0       11        1      617
# 0.174316 0.183594         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.178149
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 2--------------------
# -------------------step: .06--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.06
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0        9        1      614
# 0.843750 0.750000           32           32.0       12       12      617
# 0.843750 0.843750           64           64.0       22        1      615
# 0.804688 0.765625          128          128.0       18       15      618
# 0.691406 0.578125          256          256.0       25        1      615
# 0.576172 0.460938          512          512.0        3        3      617
# 0.427734 0.279297         1024         1024.0       16       16      613
# 0.316406 0.205078         2048         2048.0       15       15      617
# 0.220459 0.124512         4096         4096.0       22       22      617
# 0.153846 0.153846         8192         8192.0       15       15      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 2
# weighted example sum = 12620.000000
# weighted label sum = 0.000000
# average loss = 0.079886 h
# total feature number = 7771444
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 2--------------------
# --------------------step: .06---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.062500 0.062500           32           32.0        5        5      616
# 0.031250 0.000000           64           64.0       20       20      616
# 0.023438 0.015625          128          128.0       14       14      618
# 0.023438 0.023438          256          256.0        4        4      616
# 0.035156 0.046875          512          512.0        4        4      616
# 0.040039 0.044922         1024         1024.0        3        3      616
# 0.041504 0.042969         2048         2048.0       11       11      617
# 0.045166 0.048828         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.048780
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 2--------------------
# -------------------step: .12--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.12
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0        9        1      614
# 0.875000 0.812500           32           32.0       12       12      617
# 0.859375 0.843750           64           64.0       22       20      615
# 0.843750 0.828125          128          128.0       18       15      618
# 0.730469 0.617188          256          256.0       25        1      615
# 0.617188 0.503906          512          512.0        3        3      617
# 0.486328 0.355469         1024         1024.0       16       16      613
# 0.364258 0.242188         2048         2048.0       15       15      617
# 0.263428 0.162598         4096         4096.0       22       22      617
# 0.190110 0.190110         8192         8192.0       15       15      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 2
# weighted example sum = 12620.000000
# weighted label sum = 0.000000
# average loss = 0.101284 h
# total feature number = 7771444
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 2--------------------
# --------------------step: .12---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.062500 0.062500           32           32.0        5        5      616
# 0.031250 0.000000           64           64.0       20       20      616
# 0.039062 0.046875          128          128.0       14       14      618
# 0.042969 0.046875          256          256.0        4        4      616
# 0.041016 0.039062          512          512.0        4        4      616
# 0.048828 0.056641         1024         1024.0        3        3      616
# 0.048828 0.048828         2048         2048.0       11       11      617
# 0.057129 0.065430         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.061332
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 2--------------------
# -------------------step: .25--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.25
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0        9        1      614
# 0.875000 0.812500           32           32.0       12       12      617
# 0.859375 0.843750           64           64.0       22        1      615
# 0.851562 0.843750          128          128.0       18       12      618
# 0.777344 0.703125          256          256.0       25        1      615
# 0.669922 0.562500          512          512.0        3        1      617
# 0.555664 0.441406         1024         1024.0       16       16      613
# 0.431152 0.306641         2048         2048.0       15       15      617
# 0.323730 0.216309         4096         4096.0       22       22      617
# 0.219780 0.219780         8192         8192.0       15       15      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 2
# weighted example sum = 12620.000000
# weighted label sum = 0.000000
# average loss = 0.134094 h
# total feature number = 7771444
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 2--------------------
# --------------------step: .25---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.125000 0.125000           16           16.0       22       22      618
# 0.093750 0.062500           32           32.0        5        5      616
# 0.062500 0.031250           64           64.0       20       20      616
# 0.070312 0.078125          128          128.0       14       14      618
# 0.066406 0.062500          256          256.0        4        4      616
# 0.060547 0.054688          512          512.0        4        4      616
# 0.074219 0.087891         1024         1024.0        3        3      616
# 0.080078 0.085938         2048         2048.0       11       11      617
# 0.091797 0.103516         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.095849
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 2--------------------
# -------------------step: .50--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0        9        1      614
# 0.875000 0.812500           32           32.0       12       12      617
# 0.859375 0.843750           64           64.0       22        1      615
# 0.843750 0.828125          128          128.0       18       15      618
# 0.781250 0.718750          256          256.0       25        1      615
# 0.673828 0.566406          512          512.0        3       23      617
# 0.558594 0.443359         1024         1024.0       16       16      613
# 0.445312 0.332031         2048         2048.0       15       15      617
# 0.347412 0.249512         4096         4096.0       22       22      617
# 0.248352 0.248352         8192         8192.0       15       15      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 2
# weighted example sum = 12620.000000
# weighted label sum = 0.000000
# average loss = 0.141227 h
# total feature number = 7771444
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 2--------------------
# --------------------step: .50---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.062500 0.062500           32           32.0        5        5      616
# 0.046875 0.031250           64           64.0       20       20      616
# 0.070312 0.093750          128          128.0       14       14      618
# 0.070312 0.070312          256          256.0        4        4      616
# 0.083984 0.097656          512          512.0        4        4      616
# 0.094727 0.105469         1024         1024.0        3        3      616
# 0.099609 0.104492         2048         2048.0       11       11      617
# 0.111328 0.123047         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.117244
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 2--------------------
# -------------------step: 1--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 1
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0        9        1      614
# 0.875000 0.812500           32           32.0       12       12      617
# 0.859375 0.843750           64           64.0       22        1      615
# 0.843750 0.828125          128          128.0       18       15      618
# 0.785156 0.726562          256          256.0       25        1      615
# 0.691406 0.597656          512          512.0        3       23      617
# 0.574219 0.457031         1024         1024.0       16        2      613
# 0.462891 0.351562         2048         2048.0       15       15      617
# 0.368164 0.273438         4096         4096.0       22       22      617
# 0.263736 0.263736         8192         8192.0       15       15      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 2
# weighted example sum = 12620.000000
# weighted label sum = 0.000000
# average loss = 0.155492 h
# total feature number = 7771444
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 2--------------------
# --------------------step: 1---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.250000 0.500000            8            8.0       14       13      613
# 0.125000 0.000000           16           16.0       22       22      618
# 0.125000 0.125000           32           32.0        5        5      616
# 0.093750 0.062500           64           64.0       20       20      616
# 0.109375 0.125000          128          128.0       14       14      618
# 0.101562 0.093750          256          256.0        4        4      616
# 0.113281 0.125000          512          512.0        4        4      616
# 0.127930 0.142578         1024         1024.0        3        3      616
# 0.124023 0.120117         2048         2048.0       11       11      617
# 0.134033 0.144043         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.138211
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 2--------------------
# -------------------step: 2--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 2
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0        9        1      614
# 0.875000 0.812500           32           32.0       12       12      617
# 0.859375 0.843750           64           64.0       22        1      615
# 0.843750 0.828125          128          128.0       18       15      618
# 0.769531 0.695312          256          256.0       25        1      615
# 0.673828 0.578125          512          512.0        3        1      617
# 0.576172 0.478516         1024         1024.0       16        2      613
# 0.470215 0.364258         2048         2048.0       15       15      617
# 0.375732 0.281250         4096         4096.0       22       22      617
# 0.280220 0.280220         8192         8192.0       15       15      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 2
# weighted example sum = 12620.000000
# weighted label sum = 0.000000
# average loss = 0.156919 h
# total feature number = 7771444
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 2--------------------
# --------------------step: 2---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.062500 0.062500           32           32.0        5        5      616
# 0.046875 0.031250           64           64.0       20       20      616
# 0.093750 0.140625          128          128.0       14       14      618
# 0.089844 0.085938          256          256.0        4        4      616
# 0.095703 0.101562          512          512.0        4        4      616
# 0.109375 0.123047         1024         1024.0        3        3      616
# 0.111816 0.114258         2048         2048.0       11       11      617
# 0.122803 0.133789         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.126801
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# -------------------round: 2--------------------
# -------------------step: 4--------------------
#
# Script started, file is train_log.txt
# final_regressor = oaa.model
# Num weight bits = 18
# learning rate = 4
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14        1      613
# 0.937500 1.000000           16           16.0        9        1      614
# 0.875000 0.812500           32           32.0       12       12      617
# 0.859375 0.843750           64           64.0       22        1      615
# 0.843750 0.828125          128          128.0       18       15      618
# 0.777344 0.710938          256          256.0       25        1      615
# 0.681641 0.585938          512          512.0        3        1      617
# 0.581055 0.480469         1024         1024.0       16        1      613
# 0.478516 0.375977         2048         2048.0       15       15      617
# 0.378418 0.278320         4096         4096.0       22       22      617
# 0.289011 0.289011         8192         8192.0       15       15      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 2
# weighted example sum = 12620.000000
# weighted label sum = 0.000000
# average loss = 0.172611 h
# total feature number = 7771444
# Script done, file is train_log.txt
#
# --------------------oaa test------------------------
# --------------------round: 2--------------------
# --------------------step: 4---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.062500 0.000000           16           16.0       22       22      618
# 0.093750 0.125000           32           32.0        5        5      616
# 0.062500 0.031250           64           64.0       20       20      616
# 0.109375 0.156250          128          128.0       14       14      618
# 0.093750 0.078125          256          256.0        4        4      616
# 0.107422 0.121094          512          512.0        4        4      616
# 0.124023 0.140625         1024         1024.0        3        3      616
# 0.121094 0.118164         2048         2048.0       11       11      617
# 0.130127 0.139160         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.132934
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------oaa train------------------------
# ...
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.250000 0.375000           16           16.0       22       16      618
# 0.187500 0.125000           32           32.0        5        5      616
# 0.203125 0.218750           64           64.0       20       20      616
# 0.148438 0.093750          128          128.0       14       14      618
# 0.125000 0.101562          256          256.0        4       22      616
# 0.109375 0.093750          512          512.0        4        4      616
# 0.107422 0.105469         1024         1024.0        3        3      616
# 0.106934 0.106445         2048         2048.0       11       11      617
# 0.104248 0.101562         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.097704
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------ect train------------------------
# -------------------round: 20--------------------
# -------------------step: .50--------------------
#
# Script started, file is train_log.txt
# final_regressor = ect.model
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14       11      613
# 0.937500 1.000000           16           16.0        9        6      614
# 0.937500 0.937500           32           32.0       12       12      617
# 0.828125 0.718750           64           64.0       22       16      615
# 0.773438 0.718750          128          128.0       18        6      618
# 0.707031 0.640625          256          256.0       25       15      615
# 0.613281 0.519531          512          512.0        3       26      617
# 0.507812 0.402344         1024         1024.0       16        4      613
# 0.424316 0.340820         2048         2048.0       15       15      617
# 0.351807 0.279297         4096         4096.0       22       22      617
# 0.278022 0.278022         8192         8192.0       15       15      615 h
# 0.250000 0.221978        16384        16384.0        1        1      612 h
# 0.224725 0.199451        32768        32768.0       11       11      615 h
# 0.205632 0.186538        65536        65536.0       21        5      618 h
#
# finished run
# number of examples per pass = 6310
# passes used = 17
# weighted example sum = 107270.000000
# weighted label sum = 0.000000
# average loss = 0.175464 h
# total feature number = 66057274
# Script done, file is train_log.txt
#
# --------------------ect test------------------------
# --------------------round: 20--------------------
# --------------------step: .50---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.250000 0.375000           16           16.0       22       16      618
# 0.156250 0.062500           32           32.0        5        5      616
# 0.203125 0.250000           64           64.0       20       20      616
# 0.148438 0.093750          128          128.0       14       14      618
# 0.136719 0.125000          256          256.0        4       22      616
# 0.123047 0.109375          512          512.0        4        4      616
# 0.117188 0.111328         1024         1024.0        3        3      616
# 0.113281 0.109375         2048         2048.0       11       11      617
# 0.115234 0.117188         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.109827
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------ect train------------------------
# -------------------round: 20--------------------
# -------------------step: 1--------------------
#
# Script started, file is train_log.txt
# final_regressor = ect.model
# Num weight bits = 18
# learning rate = 1
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14       11      613
# 0.937500 1.000000           16           16.0        9        6      614
# 0.937500 0.937500           32           32.0       12       12      617
# 0.781250 0.625000           64           64.0       22       16      615
# 0.757812 0.734375          128          128.0       18       23      618
# 0.722656 0.687500          256          256.0       25       15      615
# 0.615234 0.507812          512          512.0        3       26      617
# 0.512695 0.410156         1024         1024.0       16       16      613
# 0.426758 0.340820         2048         2048.0       15       15      617
# 0.354248 0.281738         4096         4096.0       22       22      617
# 0.286813 0.286813         8192         8192.0       15       15      615 h
# 0.254396 0.221978        16384        16384.0        1        1      612 h
# 0.223901 0.193407        32768        32768.0       11       11      615 h
# 0.202747 0.181593        65536        65536.0       21        5      618 h
#
# finished run
# number of examples per pass = 6310
# passes used = 12
# weighted example sum = 75720.000000
# weighted label sum = 0.000000
# average loss = 0.178317 h
# total feature number = 46628664
# Script done, file is train_log.txt
#
# --------------------ect test------------------------
# --------------------round: 20--------------------
# --------------------step: 1---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.250000 0.375000           16           16.0       22       16      618
# 0.156250 0.062500           32           32.0        5        5      616
# 0.171875 0.187500           64           64.0       20       20      616
# 0.132812 0.093750          128          128.0       14       14      618
# 0.121094 0.109375          256          256.0        4       22      616
# 0.121094 0.121094          512          512.0        4        4      616
# 0.114258 0.107422         1024         1024.0        3        3      616
# 0.116699 0.119141         2048         2048.0       11       11      617
# 0.122314 0.127930         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.118671
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------ect train------------------------
# -------------------round: 20--------------------
# -------------------step: 2--------------------
#
# Script started, file is train_log.txt
# final_regressor = ect.model
# Num weight bits = 18
# learning rate = 2
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14       11      613
# 0.937500 1.000000           16           16.0        9        6      614
# 0.937500 0.937500           32           32.0       12       12      617
# 0.781250 0.625000           64           64.0       22       16      615
# 0.765625 0.750000          128          128.0       18       23      618
# 0.710938 0.656250          256          256.0       25       15      615
# 0.619141 0.527344          512          512.0        3       17      617
# 0.525391 0.431641         1024         1024.0       16        4      613
# 0.434082 0.342773         2048         2048.0       15       15      617
# 0.355957 0.277832         4096         4096.0       22       22      617
# 0.296703 0.296703         8192         8192.0       15       15      615 h
# 0.258242 0.219780        16384        16384.0        1        1      612 h
# 0.221429 0.184615        32768        32768.0       11       11      615 h
#
# finished run
# number of examples per pass = 6310
# passes used = 9
# weighted example sum = 56790.000000
# weighted label sum = 0.000000
# average loss = 0.188302 h
# total feature number = 34971498
# Script done, file is train_log.txt
#
# --------------------ect test------------------------
# --------------------round: 20--------------------
# --------------------step: 2---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.250000 0.500000            4            4.0        6       19      617
# 0.250000 0.250000            8            8.0       14       14      613
# 0.312500 0.375000           16           16.0       22       16      618
# 0.218750 0.125000           32           32.0        5        5      616
# 0.203125 0.187500           64           64.0       20       20      616
# 0.164062 0.125000          128          128.0       14       14      618
# 0.132812 0.101562          256          256.0        4       22      616
# 0.132812 0.132812          512          512.0        4        4      616
# 0.128906 0.125000         1024         1024.0        3        3      616
# 0.131836 0.134766         2048         2048.0       11       11      617
# 0.136230 0.140625         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.134931
# total feature number = 4317437
# Script done, file is test_log.txt
#
# -------------------ect train------------------------
# -------------------round: 20--------------------
# -------------------step: 4--------------------
#
# Script started, file is train_log.txt
# final_regressor = ect.model
# Num weight bits = 18
# learning rate = 4
# initial_t = 1
# power_t = 0.5
# decay_learning_rate = 1
# using cache_file = cache_train
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 1.000000 1.000000            1            1.0       12        1      617
# 1.000000 1.000000            2            2.0       15       12      616
# 1.000000 1.000000            4            4.0        6       11      617
# 0.875000 0.750000            8            8.0       14       11      613
# 0.937500 1.000000           16           16.0        9        6      614
# 0.937500 0.937500           32           32.0       12       12      617
# 0.781250 0.625000           64           64.0       22       16      615
# 0.765625 0.750000          128          128.0       18       23      618
# 0.691406 0.617188          256          256.0       25       15      615
# 0.607422 0.523438          512          512.0        3       26      617
# 0.516602 0.425781         1024         1024.0       16        4      613
# 0.429199 0.341797         2048         2048.0       15       15      617
# 0.351074 0.272949         4096         4096.0       22       22      617
# 0.285714 0.285714         8192         8192.0       15       15      615 h
# 0.254396 0.223077        16384        16384.0        1        1      612 h
# 0.224451 0.194505        32768        32768.0       11       11      615 h
# 0.203846 0.183242        65536        65536.0       21        5      618 h
#
# finished run
# number of examples per pass = 6310
# passes used = 18
# weighted example sum = 113580.000000
# weighted label sum = 0.000000
# average loss = 0.178317 h
# total feature number = 69942996
# Script done, file is train_log.txt
#
# --------------------ect test------------------------
# --------------------round: 20--------------------
# --------------------step: 4---------------------
#
# Script started, file is test_log.txt
# only testing
# Num weight bits = 18
# learning rate = 0.5
# initial_t = 0
# power_t = 0.5
# using cache_file = cache_test
# ignoring text input in favor of cache input
# num sources = 1
# average  since         example        example  current  current  current
# loss     last          counter         weight    label  predict features
# 0.000000 0.000000            1            1.0       12       12      617
# 0.000000 0.000000            2            2.0       15       15      616
# 0.000000 0.000000            4            4.0        6        6      617
# 0.125000 0.250000            8            8.0       14       14      613
# 0.312500 0.500000           16           16.0       22       16      618
# 0.187500 0.062500           32           32.0        5        5      616
# 0.218750 0.250000           64           64.0       20       20      616
# 0.156250 0.093750          128          128.0       14       14      618
# 0.152344 0.148438          256          256.0        4       22      616
# 0.136719 0.121094          512          512.0        4        4      616
# 0.123047 0.109375         1024         1024.0        3        3      616
# 0.120117 0.117188         2048         2048.0       11       11      617
# 0.120361 0.120605         4096         4096.0       16       16      614
#
# finished run
# number of examples per pass = 7011
# passes used = 1
# weighted example sum = 7011.000000
# weighted label sum = 0.000000
# average loss = 0.112537
# total feature number = 4317437
# Script done, file is test_log.txt

# %%
import pandas as pd

#load oaa_loss.csv
oaa_loss = pd.read_csv('oaa_loss.csv')
oaa_loss = oaa_loss.round(4) # keep 4 digits
oaa_train_loss = oaa_loss[oaa_loss['train/test']==1] # split to test loss and train loss
oaa_test_loss = oaa_loss[oaa_loss['train/test']==0]

ect_loss = pd.read_csv('ect_loss.csv')
ect_loss = ect_loss.round(4)
ect_train_loss = ect_loss[ect_loss['train/test']==1]
ect_test_loss = ect_loss[ect_loss['train/test']==0]

# %%
# data visualization with bokeh

from bokeh.io import output_notebook, show
from bokeh.models import LinearColorMapper, ColorBar, ColumnDataSource, LabelSet
from bokeh.palettes import Magma256, Viridis256
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.models import HoverTool
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="52687e94-a8f0-4af4-bd9f-adbf04995694">Loading BokehJS ...</span>
#     </div>

# %%
# prepare data
source_ect = ColumnDataSource(ect_test_loss)
source_oaa = ColumnDataSource(oaa_test_loss)

# define color map
color_mapper1 = LinearColorMapper(palette=Viridis256,
                                  low = 0,
                                 #low=ect_test_loss.average_loss.min(),
                                 high = 0.21)
                                 #high=ect_test_loss.average_loss.max())
color_mapper2 = LinearColorMapper(palette=Viridis256,
                                  low = 0,
                                 #low=oaa_test_loss.average_loss.min(),
                                  high = 0.21)
                                 #high=oaa_test_loss.average_loss.max())

# define color bar
color_bar1 = ColorBar(color_mapper=color_mapper1, label_standoff=12, location=(0,0), title='average_loss')
color_bar2 = ColorBar(color_mapper=color_mapper2, label_standoff=12, location=(0,0), title='average_loss')

# define hover tool
hover1 = HoverTool(tooltips=[("Method", "ect"),
                            ("passes", "@passes"),
                            ("learning_rate", "@learning_rate"),
                            ("average_loss", "@average_loss"),])
hover2 = HoverTool(tooltips=[("Method", "oaa"),
                            ("passes", "@passes"),
                            ("learning_rate", "@learning_rate"),
                            ("average_loss", "@average_loss"),])

# define figure
s1 = figure(plot_width = 400,
            plot_height= 400,
            x_axis_type='log',
            tools=[hover1],
            title = 'ect Test Loss')
# define scatter plot
s1.circle(x = 'learning_rate',
          y = 'passes',
          fill_color={'field': 'average_loss', 'transform': color_mapper1},
          line_color='black',
          size = 10,
          source = source_ect)
#s1.add_layout(color_bar1, 'left')

# define second figure
s2 = figure(plot_width = 400,
            plot_height= 400,
            x_axis_type='log',
            tools=[hover2],
            title = 'oaa Test Loss')
# define second scatter plot
s2.circle(x = 'learning_rate',
          y = 'passes',
          size = 10,
          fill_color={'field': 'average_loss', 'transform': color_mapper2},
          line_color='black',
          source = source_oaa)

# add color bar
s2.add_layout(color_bar2, 'right')

# two plot on same row
p = gridplot([[s1, s2]])

# display
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="07480216-9c84-4cdd-944e-e1d63242181b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("07480216-9c84-4cdd-944e-e1d63242181b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("07480216-9c84-4cdd-944e-e1d63242181b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '07480216-9c84-4cdd-944e-e1d63242181b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"63e796b2-71ac-4518-9383-76c95b974ed7":{"roots":{"references":[{"attributes":{"callback":null},"id":"71f7ed2a-d179-4281-93cc-26f8129eeeef","type":"DataRange1d"},{"attributes":{},"id":"95d28d1e-b78a-492b-9ea7-82c829424b73","type":"BasicTicker"},{"attributes":{"children":[{"id":"1864731e-8171-4e57-ad3a-b197996d7d4b","subtype":"Figure","type":"Plot"},{"id":"8f9398b2-e00f-44d4-b865-cf592cac02a4","subtype":"Figure","type":"Plot"}]},"id":"6eb7fabf-ee69-429c-a3f5-0f8b419ee7cc","type":"Row"},{"attributes":{"dimension":1,"plot":{"id":"8f9398b2-e00f-44d4-b865-cf592cac02a4","subtype":"Figure","type":"Plot"},"ticker":{"id":"95d28d1e-b78a-492b-9ea7-82c829424b73","type":"BasicTicker"}},"id":"55a4f36d-218d-4731-a81a-debcbc7a00c1","type":"Grid"},{"attributes":{"fill_color":{"field":"average_loss","transform":{"id":"171954e9-846a-4d28-9825-ac41e4a44bb5","type":"LinearColorMapper"}},"size":{"units":"screen","value":10},"x":{"field":"learning_rate"},"y":{"field":"passes"}},"id":"bdeacf15-e973-4b23-a01d-f1e50b68a26f","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"learning_rate"},"y":{"field":"passes"}},"id":"abb1f690-d75b-4ddf-88ed-d18bf8dcee12","type":"Circle"},{"attributes":{},"id":"922b01ec-3808-449f-abcb-791934c9a91e","type":"BasicTickFormatter"},{"attributes":{"ticker":null},"id":"bb63824f-45fb-4029-834a-e29afee199fd","type":"LogTickFormatter"},{"attributes":{"data_source":{"id":"33edeaca-d878-41a6-a475-c3d7cb465b84","type":"ColumnDataSource"},"glyph":{"id":"bdeacf15-e973-4b23-a01d-f1e50b68a26f","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"abb1f690-d75b-4ddf-88ed-d18bf8dcee12","type":"Circle"},"selection_glyph":null},"id":"90e41a8b-6f1f-4b6a-ad25-d45d0c710cf5","type":"GlyphRenderer"},{"attributes":{},"id":"6770085e-05f5-4172-84d3-f3c5fcc70d22","type":"BasicTickFormatter"},{"attributes":{},"id":"6cf4d777-f95f-4d0f-91e7-19e33ebf9cf5","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"d163ce2d-708b-4410-b181-deed5fed8a54","type":"HoverTool"}]},"id":"f57d59b6-3977-493a-b0de-cea02d98efbf","type":"Toolbar"},{"attributes":{"children":[{"id":"6a7d862a-567e-482f-8550-d36241f4fa64","type":"ToolbarBox"},{"id":"52b4aae0-4348-4b57-9fcb-5128b1eefe76","type":"Column"}]},"id":"fb81431a-c96b-46d2-9c71-713b6cac0a03","type":"Column"},{"attributes":{"callback":null},"id":"7994ce03-de4a-411e-a804-f6ca68f21562","type":"DataRange1d"},{"attributes":{"num_minor_ticks":10},"id":"b8689609-1f82-4ccf-b0f0-18d57f8a65d0","type":"LogTicker"},{"attributes":{"fill_color":{"field":"average_loss","transform":{"id":"66226e07-c585-49ec-a51d-0244b96b92b9","type":"LinearColorMapper"}},"size":{"units":"screen","value":10},"x":{"field":"learning_rate"},"y":{"field":"passes"}},"id":"1d69d224-2b3f-4262-a4c8-95b408282d0b","type":"Circle"},{"attributes":{"plot":null,"text":"ect Test Loss"},"id":"9fbec989-7eaa-454d-9d3c-803927278f85","type":"Title"},{"attributes":{"callback":null,"column_names":["train/test","learning_rate","passes","average_loss","index"],"data":{"average_loss":[0.1704,0.1819,0.1913,0.1928,0.2097,0.187,0.191,0.1459,0.1512,0.1617,0.1727,0.1677,0.1871,0.1749,0.1332,0.1358,0.1429,0.1569,0.1672,0.1522,0.1436,0.1269,0.1289,0.1356,0.1421,0.1341,0.1476,0.1314,0.1205,0.1214,0.1295,0.1332,0.1449,0.1299,0.1476,0.1161,0.1184,0.1234,0.1285,0.1215,0.1349,0.1249,0.1138,0.1134,0.1202,0.1232,0.1192,0.1225,0.1152,0.1108,0.1107,0.1165,0.1202,0.1204,0.1338,0.1208,0.1093,0.11,0.1127,0.1187,0.1187,0.1349,0.1172,0.1083,0.1083,0.11,0.1182,0.1142,0.1349,0.1298,0.1075,0.1061,0.1073,0.1171,0.1144,0.1349,0.111,0.1061,0.1031,0.1053,0.115,0.1187,0.1349,0.1197,0.1055,0.1018,0.1024,0.113,0.1187,0.1349,0.1225,0.1041,0.1061,0.1017,0.1098,0.1187,0.1349,0.1211,0.1061,0.1061,0.1001,0.1081,0.1187,0.1349,0.1125,0.1061,0.1061,0.0998,0.1075,0.1 ...

# %%
print('minimum ect test average loss')
ect_test_loss[ect_test_loss.average_loss == ect_test_loss.average_loss.min()]
# Out:
#      train/test  learning_rate  passes  average_loss
# 271           0           0.25      20        0.0977

# %%
print('minimum ect test average loss')
oaa_test_loss[oaa_test_loss.average_loss == oaa_test_loss.average_loss.min()]
# Out:
# minimum ect test average loss
#      train/test  learning_rate  passes  average_loss
# 197           0           0.06      15        0.0218
